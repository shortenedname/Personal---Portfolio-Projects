# %%
#import libraries
#loading in trhe original .csv file and looking at the head and filling in empty spaces
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

master_df = pd.read_csv('all_data.csv')
master_df.fillna(0)
master_df.head(32)
# Out:
#    Country  Year  Life expectancy at birth (years)           GDP
# 0    Chile  2000                              77.3  7.786093e+10
# 1    Chile  2001                              77.3  7.097992e+10
# 2    Chile  2002                              77.8  6.973681e+10
# 3    Chile  2003                              77.9  7.564346e+10
# 4    Chile  2004                              78.0  9.921039e+10
# 5    Chile  2005                              78.4  1.229650e+11
# 6    Chile  2006                              78.9  1.547880e+11
# 7    Chile  2007                              78.9  1.736060e+11
# 8    Chile  2008                              79.6  1.796380e+11
# 9    Chile  2009                              79.3  1.723890e+11
# 10   Chile  2010                              79.1  2.185380e+11
# 11   Chile  2011                              79.8  2.522520e+11
# 12   Chile  2012                              79.9  2.671220e+11
# ...

# %%
new_list = []
for index, row in master_df.iterrows():
    new_list.append(list(row))

print(new_list)

chile_list = []
for obj in new_list:
    if obj[0] == 'Chile':
        chile_list.append(obj)

print(chile_list)
# Out:
# [['Chile', 2000, 77.3, 77860932152.0], ['Chile', 2001, 77.3, 70979923960.0], ['Chile', 2002, 77.8, 69736811435.0], ['Chile', 2003, 77.9, 75643459840.0], ['Chile', 2004, 78.0, 99210392858.0], ['Chile', 2005, 78.4, 122965000000.0], ['Chile', 2006, 78.9, 154788000000.0], ['Chile', 2007, 78.9, 173606000000.0], ['Chile', 2008, 79.6, 179638000000.0], ['Chile', 2009, 79.3, 172389000000.0], ['Chile', 2010, 79.1, 218538000000.0], ['Chile', 2011, 79.8, 252252000000.0], ['Chile', 2012, 79.9, 267122000000.0], ['Chile', 2013, 80.1, 278384000000.0], ['Chile', 2014, 80.3, 260990000000.0], ['Chile', 2015, 80.5, 242518000000.0], ['China', 2000, 71.7, 1211350000000.0], ['China', 2001, 72.2, 1339400000000.0], ['China', 2002, 72.7, 1470550000000.0], ['China', 2003, 73.1, 1660290000000.0], ['China', 2004, 73.5, 1955350000000.0], ['China', 2005, 73.9, 2285970000000.0], ['China', 2006, 74.2, 2752130000000.0], ['China', 2007, 74.4, 3552180000000.0], ['China', 2008, 74.5, 4598210000000.0], ['China', 2009, 74
# ...
